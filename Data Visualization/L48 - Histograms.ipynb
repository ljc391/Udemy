# %%
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
#
from scipy import stats

# %%
#Plotting

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#To see plot in jupyter notebook
# %matplotlib inline

# %%
url = "http://en.wikipedia.org/wiki/Histogram"

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# default create 10 bins
# Out:
# (array([ 11.,  12.,  14.,  25.,  15.,  12.,   5.,   1.,   4.,   1.]),
#  array([-1.78711644, -1.29811057, -0.8091047 , -0.32009882,  0.16890705,
#          0.65791293,  1.1469188 ,  1.63592468,  2.12493055,  2.61393643,
#          3.1029423 ]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)
plt.hist(dataset2, color = 'indianred')
# Out:
# (array([  6.,   2.,  12.,  16.,  23.,  13.,   5.,   2.,   0.,   1.]),
#  array([-2.4693057 , -1.88574853, -1.30219136, -0.71863419, -0.13507702,
#          0.44848015,  1.03203732,  1.61559449,  2.19915166,  2.78270883,
#          3.366266  ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Both histogram on the same plot

# %%
#set normed true , because have diff nums of dataset
plt.hist(dataset1, normed = True, color = "indianred", alpha = 0.5, bins = 20)
plt.hist(dataset2, normed = True, alpha = 0.5, bins = 20)
# Out:
# (array([ 0.12852211,  0.12852211,  0.08568141,  0.        ,  0.21420352,
#          0.29988493,  0.42840704,  0.25704422,  0.51408845,  0.47124774,
#          0.38556634,  0.17136282,  0.17136282,  0.0428407 ,  0.08568141,
#          0.        ,  0.        ,  0.        ,  0.        ,  0.0428407 ]),
#  array([-2.4693057 , -2.17752712, -1.88574853, -1.59396995, -1.30219136,
#         -1.01041278, -0.71863419, -0.42685561, -0.13507702,  0.15670156,
#          0.44848015,  0.74025873,  1.03203732,  1.3238159 ,  1.61559449,
#          1.90737307,  2.19915166,  2.49093024,  2.78270883,  3.07448742,
#          3.366266  ]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %% [markdown]
# ## Join plot for two data set

# %%
sns.jointplot(data1, data2)

# %%
sns.jointplot(data1, data2, kind = "hex")
